# %%
# %cd "C:/users/prashant/desktop"
# Out:
# C:\users\prashant\desktop

# %%
import pandas as pd
import quandl
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import sklearn

# %%
with open(r'C:\users\prashant\desktop\API.txt','r')as f: auth_token=f.read()

# %%
df=quandl.get('EOD/AAPL',authtoken = auth_token)

# %%
df=pd.read_csv('C:/users/prashant/desktop/EOD-AAPL.csv')

# %%
df
# Out:
#             Date    Open     High      Low    Close      Volume  Dividend  \
# 0     2017-12-28  171.00  171.850  170.480  171.080  16480187.0       0.0
# 1     2017-12-27  170.10  170.780  169.710  170.600  21498213.0       0.0
# 2     2017-12-26  170.80  171.470  169.679  170.570  33185536.0       0.0
# 3     2017-12-22  174.68  175.424  174.500  175.010  16349444.0       0.0
# 4     2017-12-21  174.17  176.020  174.100  175.010  20949896.0       0.0
# ...          ...     ...      ...      ...      ...         ...       ...
# 1085  2013-09-09  505.00  507.920  503.480  506.170  12167400.0       0.0
# 1086  2013-09-06  498.44  499.380  489.950  498.220  12840200.0       0.0
# 1087  2013-09-05  500.25  500.680  493.640  495.270   8441700.0       0.0
# 1088  2013-09-04  499.56  502.240  496.280  498.691  12322600.0       0.0
# 1089  2013-09-03  493.10  500.600  487.350  488.580  11854600.0       0.0
#
#       Split   Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume
# ...

# %%
df.shape
# Out:
# (1090, 13)

# %%
df['HL_PCT']=(df['Adj_High'])-(df['Adj_Low'])/df['Adj_Close']*100

# %%
df
# Out:
#             Date    Open     High      Low    Close      Volume  Dividend  \
# 0     2017-12-28  171.00  171.850  170.480  171.080  16480187.0       0.0
# 1     2017-12-27  170.10  170.780  169.710  170.600  21498213.0       0.0
# 2     2017-12-26  170.80  171.470  169.679  170.570  33185536.0       0.0
# 3     2017-12-22  174.68  175.424  174.500  175.010  16349444.0       0.0
# 4     2017-12-21  174.17  176.020  174.100  175.010  20949896.0       0.0
# ...          ...     ...      ...      ...      ...         ...       ...
# 1085  2013-09-09  505.00  507.920  503.480  506.170  12167400.0       0.0
# 1086  2013-09-06  498.44  499.380  489.950  498.220  12840200.0       0.0
# 1087  2013-09-05  500.25  500.680  493.640  495.270   8441700.0       0.0
# 1088  2013-09-04  499.56  502.240  496.280  498.691  12322600.0       0.0
# 1089  2013-09-03  493.10  500.600  487.350  488.580  11854600.0       0.0
#
#       Split   Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume  \
# ...

# %%
df['PCT_change']=(df['Adj_Close'])-df['Adj_Open']/df['Adj_Open']*100

# %%
df
# Out:
#             Date    Open     High      Low    Close      Volume  Dividend  \
# 0     2017-12-28  171.00  171.850  170.480  171.080  16480187.0       0.0
# 1     2017-12-27  170.10  170.780  169.710  170.600  21498213.0       0.0
# 2     2017-12-26  170.80  171.470  169.679  170.570  33185536.0       0.0
# 3     2017-12-22  174.68  175.424  174.500  175.010  16349444.0       0.0
# 4     2017-12-21  174.17  176.020  174.100  175.010  20949896.0       0.0
# ...          ...     ...      ...      ...      ...         ...       ...
# 1085  2013-09-09  505.00  507.920  503.480  506.170  12167400.0       0.0
# 1086  2013-09-06  498.44  499.380  489.950  498.220  12840200.0       0.0
# 1087  2013-09-05  500.25  500.680  493.640  495.270   8441700.0       0.0
# 1088  2013-09-04  499.56  502.240  496.280  498.691  12322600.0       0.0
# 1089  2013-09-03  493.10  500.600  487.350  488.580  11854600.0       0.0
#
#       Split   Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume  \
# ...

# %%
df1=df[['Adj_Close','HL_PCT','PCT_change','Adj_Volume']]

# %%
forecast_col='Adj_Close'

# %%
df.fillna(-9999,inplace=True)

# %%
forecast_out=int(math.ceil(0.1*len(df)))

# %%
df['label']=df[forecast_col].shift(-forecast_out)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#            Date    Open      High      Low   Close      Volume  Dividend  \
# 0    2017-12-28  171.00  171.8500  170.480  171.08  16480187.0       0.0
# 1    2017-12-27  170.10  170.7800  169.710  170.60  21498213.0       0.0
# 2    2017-12-26  170.80  171.4700  169.679  170.57  33185536.0       0.0
# 3    2017-12-22  174.68  175.4240  174.500  175.01  16349444.0       0.0
# 4    2017-12-21  174.17  176.0200  174.100  175.01  20949896.0       0.0
# ..          ...     ...       ...      ...     ...         ...       ...
# 976  2014-02-13  534.66  544.8500  534.200  544.43  10978500.0       0.0
# 977  2014-02-12  536.95  539.5600  533.240  535.92  11003600.0       0.0
# 978  2014-02-11  530.61  537.7500  529.500  535.96  10080600.0       0.0
# 979  2014-02-10  518.66  531.9900  518.000  528.99  12341400.0       0.0
# 980  2014-02-07  521.38  522.9299  517.380  519.68  13224300.0       0.0
#
#      Split   Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume  \
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of            Date    Open      High      Low   Close      Volume  Dividend  \
# 0    2017-12-28  171.00  171.8500  170.480  171.08  16480187.0       0.0
# 1    2017-12-27  170.10  170.7800  169.710  170.60  21498213.0       0.0
# 2    2017-12-26  170.80  171.4700  169.679  170.57  33185536.0       0.0
# 3    2017-12-22  174.68  175.4240  174.500  175.01  16349444.0       0.0
# 4    2017-12-21  174.17  176.0200  174.100  175.01  20949896.0       0.0
# ..          ...     ...       ...      ...     ...         ...       ...
# 976  2014-02-13  534.66  544.8500  534.200  544.43  10978500.0       0.0
# 977  2014-02-12  536.95  539.5600  533.240  535.92  11003600.0       0.0
# 978  2014-02-11  530.61  537.7500  529.500  535.96  10080600.0       0.0
# 979  2014-02-10  518.66  531.9900  518.000  528.99  12341400.0       0.0
# 980  2014-02-07  521.38  522.9299  517.380  519.68  13224300.0       0.0
#
# ...

# %%
X=np.array(df.drop(['label'],1))

# %%
X_forecast=X[-1:]

# %%
X=X[:-1]

# %%
y=np.array(df['label'])

# %%
y=y[:-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

clf = LinearRegression()
clf.fit(X_train,y_train)

# %%
confidence

# %%
sklearn.metrics.mean_squared_error(y_test,clf.predict(X_test))
